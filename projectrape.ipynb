# %% [markdown]
# # First let's just import the libraries

# %%
import pandas as pd
import os

# %%
#Now we will import our csv file.
#Aim EDA

# %%
df=pd.read_csv(r'C:\Users\Hanish\Desktop\prop\rape.csv')
df
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
#let's check the shape of the dataframe i.e rows*columns
df.shape
# Out:
# (1050, 11)

# %%
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %% [raw]
# The count shows the number of rows and their values present in the data
# mean is foe average of every column
# as we can observe Rape_Cases_Reported column has highest average and Victims_Above_50_Yrs column has least

# %%
#code for checking the columns name
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Area_Name                  1050 non-null   object
#  1   Year                       1050 non-null   int64
#  2   Subgroup                   1050 non-null   object
#  3   Rape_Cases_Reported        1050 non-null   int64
#  4   Victims_Above_50_Yrs       1050 non-null   int64
#  5   Victims_Between_10-14_Yrs  1050 non-null   int64
#  6   Victims_Between_14-18_Yrs  1050 non-null   int64
#  7   Victims_Between_18-30_Yrs  1050 non-null   int64
#  8   Victims_Between_30-50_Yrs  1050 non-null   int64
#  9   Victims_of_Rape_Total      1050 non-null   int64
#  10  Victims_Upto_10_Yrs        1050 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 90.4+ KB

# %%
 #code so that we can check if there is any  null value or not.
df.isnull().sum()
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %%
df.dtypes
# Out:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object

# %%
df['Area_Name'].value_counts()
# Out:
# Daman & Diu                  30
# Odisha                       30
# Meghalaya                    30
# Himachal Pradesh             30
# Dadra & Nagar Haveli         30
# Puducherry                   30
# Uttarakhand                  30
# Lakshadweep                  30
# Bihar                        30
# Tamil Nadu                   30
# Punjab                       30
# Arunachal Pradesh            30
# Sikkim                       30
# Goa                          30
# Haryana                      30
# Karnataka                    30
# Andhra Pradesh               30
# Chandigarh                   30
# Uttar Pradesh                30
# Manipur                      30
# Assam                        30
# Jharkhand                    30
# Maharashtra                  30
# Tripura                      30
# Madhya Pradesh               30
# Andaman & Nicobar Islands    30
# Rajasthan                    30
# Chhattisgarh                 30
# Nagaland                     30
# ...

# %%
df['Subgroup'].value_counts()
# Out:
# Victims of Incest Rape    350
# Victims of Other Rape     350
# Total Rape Victims        350
# Name: Subgroup, dtype: int64

# %%
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

# %%
sn.barplot(df['Year'],df['Rape_Cases_Reported'])

# %% [raw]
# The above graph shows the Rape case reported in last years
# The maximums cases was reported in year 2010
# and the minimum was in year 2003

# %%
sn.barplot(df['Subgroup'],df['Rape_Cases_Reported'])

# %%
fig=plt.figure(figsize=(55,10))
sn.barplot(df['Area_Name'],df['Victims_Upto_10_Yrs'])

# %% [raw]
# #Victims in last 10 year in different states of our nation and in continent
# maximum was in Maharastra.
# minimum is in lakshadweep

# %%
fig=plt.figure(figsize=(150,50))
sn.barplot(df['Rape_Cases_Reported'],df['Victims_Above_50_Yrs'])

# %%
fig=plt.figure(figsize=(150,20))
sn.barplot(df['Rape_Cases_Reported'],df['Victims_Between_10-14_Yrs'])

# %%
import itertools
cols=[ 'Rape_Cases_Reported','Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total','Victims_Upto_10_Yrs']
length=len(cols)
cs=["b","r","g","c","m","k","lime"]
fig=plt.figure(figsize=(20,20))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,4,j+1)
    ax=sn.distplot(df[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(df[i].mean(),linestyle="dashed",label="mean",color="k")
    plt.legend(loc="best")
    plt.title(i,color="navy")
    plt.xlabel("")

# %%
sn.heatmap(df.isnull())

# %% [raw]
#  There is not any null values in the dataset.
# if there would have any null values we could have seen yellow dash above the column

# %%
dfcor=df.corr()
dfcor
# Out:
#                                Year  Rape_Cases_Reported  \
# Year                       1.000000             0.070944
# Rape_Cases_Reported        0.070944             1.000000
# Victims_Above_50_Yrs       0.095368             0.652470
# Victims_Between_10-14_Yrs  0.057081             0.762842
# Victims_Between_14-18_Yrs  0.060579             0.780262
# Victims_Between_18-30_Yrs  0.069109             0.966432
# Victims_Between_30-50_Yrs  0.053460             0.925609
# Victims_of_Rape_Total      0.071121             0.999998
# Victims_Upto_10_Yrs        0.066608             0.665398
#
#                            Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# Year                                   0.095368                   0.057081
# Rape_Cases_Reported                    0.652470                   0.762842
# Victims_Above_50_Yrs                   1.000000                   0.595057
# Victims_Between_10-14_Yrs              0.595057                   1.000000
# ...

# %%
plt.figure(figsize=(15,7))
sn.heatmap(dfcor,cmap='Blues',annot=True)

# %% [raw]
# The above correlation states Rape cases reported according to age
# the strongest bond is with  Victims between 18-30 years which states most of the incidents were held with people whose age is betweeb 18 to 30
# and the least is with victims above 50 yrs.

# %%
df.shape
# Out:
# (1050, 11)

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %%
df['Rape_Cases_Reported'].plot.box()

# %%
df['Victims_Above_50_Yrs'].plot.box()

# %%
df['Victims_Between_10-14_Yrs'].plot.box()

# %%
df['Victims_Between_14-18_Yrs'].plot.box()

# %%
df['Victims_Between_18-30_Yrs'].plot.box()

# %%
df['Victims_Between_30-50_Yrs'].plot.box()

# %%
df['Victims_of_Rape_Total'].plot.box()

# %%
df['Victims_Upto_10_Yrs'].plot.box()

# %%
#bivariate analysis
plt.scatter(df['Year'],df['Rape_Cases_Reported'])

# %%
sn.pairplot(df)
