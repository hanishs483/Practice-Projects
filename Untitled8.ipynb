# %%
#importing the libraries
import pandas as pd
import numpy as np
import os
import warnings
import selenium 
warnings.filterwarnings('ignore')

# %%
#importing the file from github
Train=pd.read_csv(r"D:\customer\data.csv")
Train.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
pd.set_option("display.max_columns", None)
Train.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
Train.shape
# Out:
# (269, 71)

# %%
print(Train.dtypes)
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                       int64
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                               int64
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#checking unique value for every column
Train.apply(lambda x: len(x.unique()))
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
#let's check the null value
sns.heatmap(Train.isnull())

# %%
Train.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# # TRUST

# %%
sns.countplot(Train["1Gender of respondent"])
plt.title('Total Number of male and female')
plt.show()

# %%
sns.countplot(Train["2 How old are you? "])
plt.title('Age')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(Train["3 Which city do you shop online from?"])
plt.title('Location where they are shopping from')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(Train['3 Which city do you shop online from?'],Train['4 What is the Pin Code of where you shop online from?'])

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="3 Which city do you shop online from?",hue="5 Since How Long You are Shopping Online ?",data=Train)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x="3 Which city do you shop online from?",hue="6 How many times you have made an online purchase in the past 1 year?",data=Train)
plt.show()

# %%
sns.distplot(Train["7 How do you access the internet while shopping on-line?"])

# %%
sns.distplot(Train["8 Which device do you use to access the online shopping?"])

# %%
sns.distplot(Train["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])

# %%
plt.figure(figsize=(15,7))
sns.countplot(Train["28 Being able to guarantee the privacy of the customer"])

# %% [markdown]
# # SERVICE QUALITY

# %%
sns.scatterplot(x="22 Ease of navigation in website",y="24 User friendly Interface of the website",data=Train)

# %%
sns.scatterplot(x="23 Loading and processing speed",y="22 Ease of navigation in website",data=Train)

# %%
#univariate
Train['25 Convenient Payment methods'].plot.hist()

# %%
sns.scatterplot(x="27 Empathy (readiness to assist with queries) towards the customers",y="29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)",data=Train)
plt.figure(figsize=(15,55))

# %%
sns.distplot(Train["28 Being able to guarantee the privacy of the customer"])

# %% [markdown]
# # Benefit

# %%
sns.countplot(Train["19 Information on similar product to the one highlighted  is important for product comparison"])
plt.show()

# %%
sns.boxplot(Train["30 Online shopping gives monetary benefit and discounts"])
plt.show()

# %%
sns.relplot( x="31 Enjoyment is derived from shopping online",y="32 Shopping online is convenient and flexible",data=Train)

# %%
sns.jointplot(data=Train, x="41 Monetary savings", y="47 Getting value for money spent")

# %%
Train.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                              -0.034449
# 4 What is the Pin Code of where you shop online...               0.260696
# 5 Since How Long You are Shopping Online ?                      -0.046005
# 6 How many times you have made an online purcha...               0.076121
# 7 How do you access the internet while shopping...              -0.200974
# 8 Which device do you use to access the online ...              -0.241847
# 9 What is the screen size of your mobile device...              -0.058760
# 10 What is the operating system (OS) of your de...              -0.038207
# 11 What browser do you run on your device to ac...              -0.116712
# 12 Which channel did you follow to arrive at yo...              -0.166694
# 13 After first visit, how do you reach the onli...               0.104118
# ...

# %%
pd.set_option("display.max_columns", None)
Train.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
import numpy as np
from itertools import chain

# return list from series of comma-separated strings
def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

# calculate lengths of splits
qens = Train['Easy to use website or application'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
wes = pd.DataFrame({ 
                    'Easy to use website or application': chainer(Train['Easy to use website or application'])
                   })

# calculate lengths of splits
eens = Train['Visual appealing web-page layout'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
res = pd.DataFrame({ 
                    'Visual appealing web-page layout': chainer(Train['Visual appealing web-page layout'])
                   })
# calculate lengths of splits
tens = Train['Wild variety of product on offer'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
yes = pd.DataFrame({ 
                    'Wild variety of product on offer': chainer(Train['Wild variety of product on offer'])
                   })
# calculate lengths of splits
uens = Train['Complete, relevant description information of products'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
ies = pd.DataFrame({ 
                    'Complete, relevant description information of products': chainer(Train['Complete, relevant description information of products'])
                   })
# calculate lengths of splits
oens = Train['Fast loading website speed of website and application'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
pes = pd.DataFrame({ 
                    'Fast loading website speed of website and application': chainer(Train['Fast loading website speed of website and application'])
                   })
# calculate lengths of splits
aens = Train['Reliability of the website or application'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
ses = pd.DataFrame({ 
                    'Reliability of the website or application': chainer(Train['Reliability of the website or application'])
                   })
# calculate lengths of splits
dens = Train['Quickness to complete purchase'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
fes = pd.DataFrame({ 
                    'Quickness to complete purchase': chainer(Train['Quickness to complete purchase'])
                   })
# calculate lengths of splits
gens = Train['Availability of several payment options'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
hes = pd.DataFrame({ 
                    'Availability of several payment options': chainer(Train['Availability of several payment options'])
                   })

# calculate lengths of splits
lens = Train['Privacy of customers’ information'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
zes = pd.DataFrame({ 
                    'Privacy of customers’ information': chainer(Train['Privacy of customers’ information'])
                   })
# calculate lengths of splits
xens = Train['Security of customer financial information'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
ces = pd.DataFrame({ 
                    'Security of customer financial information': chainer(Train['Security of customer financial information'])
                   })
# calculate lengths of splits
cens = Train['Perceived Trustworthiness'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
ves = pd.DataFrame({ 
                    'Perceived Trustworthiness': chainer(Train['Perceived Trustworthiness'])
                   })
# calculate lengths of splits
bens = Train['Presence of online assistance through multi-channel'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
nes = pd.DataFrame({ 
                    'Presence of online assistance through multi-channel': chainer(Train['Presence of online assistance through multi-channel'])
                   })
# calculate lengths of splits
mens = Train['Longer time to get logged in (promotion, sales period)'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qes = pd.DataFrame({ 
                    'Longer time to get logged in (promotion, sales period)': chainer(Train['Longer time to get logged in (promotion, sales period)'])
                   })
# calculate lengths of splits
qqens = Train['Longer time in displaying graphics and photos (promotion, sales period)'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qqes = pd.DataFrame({ 
                    'Longer time in displaying graphics and photos (promotion, sales period)': chainer(Train['Longer time in displaying graphics and photos (promotion, sales period)'])
                   })
# calculate lengths of splits
qwens = Train['Late declaration of price (promotion, sales period)'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qwes = pd.DataFrame({ 
                    'Late declaration of price (promotion, sales period)': chainer(Train['Late declaration of price (promotion, sales period)'])
                   })
# calculate lengths of splits
qeens = Train['Longer page loading time (promotion, sales period)'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qees = pd.DataFrame({ 
                    'Longer page loading time (promotion, sales period)': chainer(Train['Longer page loading time (promotion, sales period)'])
                   })
# calculate lengths of splits
qrens = Train['Limited mode of payment on most products (promotion, sales period)'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qres = pd.DataFrame({ 
                    'Limited mode of payment on most products (promotion, sales period)': chainer(Train['Limited mode of payment on most products (promotion, sales period)'])
                   })
# calculate lengths of splits
qtens = Train['Longer delivery period'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qtes = pd.DataFrame({ 
                    'Longer delivery period': chainer(Train['Longer delivery period'])
                   })
# calculate lengths of splits
qyens = Train['Change in website/Application design'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qyes = pd.DataFrame({ 
                    'Change in website/Application design': chainer(Train['Change in website/Application design'])
                   })
# calculate lengths of splits
quens = Train['Frequent disruption when moving from one page to another'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
ques = pd.DataFrame({ 
                    'Frequent disruption when moving from one page to another': chainer(Train['Frequent disruption when moving from one page to another'])
                   })
# calculate lengths of splits
qens = Train['Website is as efficient as before'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qies = pd.DataFrame({ 
                    'Website is as efficient as before': chainer(Train['Website is as efficient as before'])
                   })
# calculate lengths of splits
qiens = Train['Which of the Indian online retailer would you recommend to a friend?'].str.split(',').map(len)

# create new dataframe, repeating or chaining as appropriate
qoes = pd.DataFrame({ 
                    'Which of the Indian online retailer would you recommend to a friend?': chainer(Train['Which of the Indian online retailer would you recommend to a friend?'])
                   })

df_row = pd.concat([wes,res,yes,ies,pes,ses,fes,hes,zes,ces,ves,nes,qes,qqes,qwes,qees,qres,qtes,qyes,ques,qies,qoes])


print(df_row)
# Out:
#     Easy to use website or application Visual appealing web-page layout  \
# 0                            Paytm.com                              NaN
# 1                            Amazon.in                              NaN
# 2                         Flipkart.com                              NaN
# 3                           Myntra.com                              NaN
# 4                         Snapdeal.com                              NaN
# ..                                 ...                              ...
# 472                                NaN                              NaN
# 473                                NaN                              NaN
# 474                                NaN                              NaN
# 475                                NaN                              NaN
# 476                                NaN                              NaN
#
#     Wild variety of product on offer  \
# 0                                NaN
# ...

# %%
df_row
# Out:
#     Easy to use website or application Visual appealing web-page layout  \
# 0                            Paytm.com                              NaN
# 1                            Amazon.in                              NaN
# 2                         Flipkart.com                              NaN
# 3                           Myntra.com                              NaN
# 4                         Snapdeal.com                              NaN
# ..                                 ...                              ...
# 472                                NaN                              NaN
# 473                                NaN                              NaN
# 474                                NaN                              NaN
# 475                                NaN                              NaN
# 476                                NaN                              NaN
#
#     Wild variety of product on offer  \
# 0                                NaN
# ...

# %%
df_row.dtypes
# Out:
# Easy to use website or application                                         object
# Visual appealing web-page layout                                           object
# Wild variety of product on offer                                           object
# Complete, relevant description information of products                     object
# Fast loading website speed of website and application                      object
# Reliability of the website or application                                  object
# Quickness to complete purchase                                             object
# Availability of several payment options                                    object
# Privacy of customers’ information                                          object
# Security of customer financial information                                 object
# Perceived Trustworthiness                                                  object
# ...

# %%
df_row
# Out:
#     Easy to use website or application Visual appealing web-page layout  \
# 0                            Paytm.com                              NaN
# 1                            Amazon.in                              NaN
# 2                         Flipkart.com                              NaN
# 3                           Myntra.com                              NaN
# 4                         Snapdeal.com                              NaN
# ..                                 ...                              ...
# 472                                NaN                              NaN
# 473                                NaN                              NaN
# 474                                NaN                              NaN
# 475                                NaN                              NaN
# 476                                NaN                              NaN
#
#     Wild variety of product on offer  \
# 0                                NaN
# ...

# %%
df_row.columns
# Out:
# Index(['Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
#        'Longer page loading time (promotion, sales period)',
#        'Limited mode of payment on most products (promotion, sales period)',
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(df_row["Easy to use website or application"])
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(df_row["Visual appealing web-page layout"])
plt.show()

# %%
df_row.columns
# Out:
# Index(['Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',
#        'Quickness to complete purchase',
#        'Availability of several payment options',
#        'Privacy of customers’ information',
#        'Security of customer financial information',
#        'Perceived Trustworthiness',
#        'Presence of online assistance through multi-channel',
#        'Longer time to get logged in (promotion, sales period)',
#        'Longer time in displaying graphics and photos (promotion, sales period)',
#        'Late declaration of price (promotion, sales period)',
#        'Longer page loading time (promotion, sales period)',
#        'Limited mode of payment on most products (promotion, sales period)',
# ...

# %%
df_row.apply(lambda x: len(x.unique()))
# Out:
# Easy to use website or application                                          8
# Visual appealing web-page layout                                            8
# Wild variety of product on offer                                            9
# Complete, relevant description information of products                      8
# Fast loading website speed of website and application                       8
# Reliability of the website or application                                   9
# Quickness to complete purchase                                              8
# Availability of several payment options                                     8
# Privacy of customers’ information                                           9
# Security of customer financial information                                  9
# Perceived Trustworthiness                                                   8
# Presence of online assistance through multi-channel                         9
# ...

# %%
df_row = df_row.astype("|S")
df_row
# Out:
#     Easy to use website or application Visual appealing web-page layout  \
# 0                         b'Paytm.com'                           b'nan'
# 1                         b'Amazon.in'                           b'nan'
# 2                     b' Flipkart.com'                           b'nan'
# 3                       b' Myntra.com'                           b'nan'
# 4                     b' Snapdeal.com'                           b'nan'
# ..                                 ...                              ...
# 472                             b'nan'                           b'nan'
# 473                             b'nan'                           b'nan'
# 474                             b'nan'                           b'nan'
# 475                             b'nan'                           b'nan'
# 476                             b'nan'                           b'nan'
#
#     Wild variety of product on offer  \
# 0                             b'nan'
# ...

# %%
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_col = ['Easy to use website or application',
       'Visual appealing web-page layout', 'Wild variety of product on offer',
       'Complete, relevant description information of products',
       'Fast loading website speed of website and application',
       'Reliability of the website or application',
       'Quickness to complete purchase',
       'Availability of several payment options',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?']
for col in cat_col:
    df_row[col] = le.fit_transform(df_row[col])

# %%
c
# Out:
#      Easy to use website or application  Visual appealing web-page layout  \
# 0                                     6                                 7
# 1                                     4                                 7
# 2                                     0                                 7
# 3                                     1                                 7
# 4                                     3                                 7
# ..                                  ...                               ...
# 472                                   7                                 7
# 473                                   7                                 7
# 474                                   7                                 7
# 475                                   7                                 7
# 476                                   7                                 7
#
#      Wild variety of product on offer  \
# 0                                   8
# ...

# %%
plt.scatter(df_row.index,df_row['Easy to use website or application'])
plt.show()

# %%
plt.pie(df_row['Quickness to complete purchase'].value_counts),
labels=['a','s',],shadow=True
# Out:
#   File "<ipython-input-56-7eb8a42fa47d>", line 2
#     labels=['a','s',],shadow=True
#            ^
# SyntaxError: cannot assign to literal

# %%
df_row.apply(lambda x: len(x.unique()))
# Out:
# Easy to use website or application                                          8
# Visual appealing web-page layout                                            8
# Wild variety of product on offer                                            9
# Complete, relevant description information of products                      8
# Fast loading website speed of website and application                       8
# Reliability of the website or application                                   9
# Quickness to complete purchase                                              8
# Availability of several payment options                                     8
# Privacy of customers’ information                                           9
# Security of customer financial information                                  9
# Perceived Trustworthiness                                                   8
# Presence of online assistance through multi-channel                         9
# ...
